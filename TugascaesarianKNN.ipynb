# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
caesarian_df = pd.read_excel("E:/1.Saya/Kuliah/Semester 7/BI/UAS/data_UAS-main/caesarian.xlsx",
                       usecols=['Usia','Kelahiran_ke-','Waktu_Kelahiran','Tekanan_darah','Kelainan_jantung', 'Caesarian'],
                             dtype={'Usia': 'int32', 'Kelahiran_ke-': 'int32', 'Waktu_Kelahiran': 'int32', 'Tekanan_darah': 'int32', 
                                    'Kelainan_jantung': 'int32', 'Caesarian': 'int32'})

# %%
caesarian_df.head()
# Out:
#    Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 0    22              1                0              2                 0
# 1    26              2                0              1                 0
# 2    26              2                1              1                 0
# 3    28              1                0              2                 0
# 4    22              2                0              1                 0
#
#    Caesarian
# 0          0
# 1          1
# 2          0
# 3          0
# 4          1

# %%
import math

dis = []
for i in range(80):
    dis.append(math.sqrt((float(caesarian_df.iloc[i]['Usia'])-25)**2+
                         (float(caesarian_df.iloc[i]['Kelahiran_ke-'])- 1)**2+
                         (float(caesarian_df.iloc[i]['Waktu_Kelahiran'])-0)**2+
                         (float(caesarian_df.iloc[i]['Tekanan_darah'])-1)**2))

# %%
caesarian_df['dis'] = dis
caesarian_df
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 0     22              1                0              2                 0
# 1     26              2                0              1                 0
# 2     26              2                1              1                 0
# 3     28              1                0              2                 0
# 4     22              2                0              1                 0
# ..   ...            ...              ...            ...               ...
# 75    27              2                1              1                 0
# 76    33              4                0              1                 0
# 77    29              2                1              2                 0
# 78    25              1                2              0                 0
# 79    24              2                2              1                 0
#
#     Caesarian       dis
# 0           0  3.162278
# 1           1  1.414214
# ...

# %%
caesarian_df.sort_values('dis')
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 16    25              1                0              1                 0
# 46    26              1                0              1                 0
# 68    25              1                0              0                 0
# 55    25              2                0              1                 0
# 30    25              1                0              0                 0
# ..   ...            ...              ...            ...               ...
# 42    36              1                1              2                 0
# 44    36              4                0              2                 1
# 18    37              3                0              1                 1
# 74    38              3                2              2                 1
# 31    40              1                0              1                 1
#
#     Caesarian        dis
# 16          0   0.000000
# 46          0   1.000000
# ...

# %%
y = caesarian_df.sort_values('dis').head(5)
y
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 16    25              1                0              1                 0
# 46    26              1                0              1                 0
# 68    25              1                0              0                 0
# 55    25              2                0              1                 0
# 30    25              1                0              0                 0
#
#     Caesarian  dis
# 16          0  0.0
# 46          0  1.0
# 68          1  1.0
# 55          0  1.0
# 30          0  1.0

# %%
z = y["Caesarian"]
z
# Out:
# 16    0
# 46    0
# 68    1
# 55    0
# 30    0
# Name: Caesarian, dtype: int32

# %%
np.mean(z)
# Out:
# 0.2

# %%
caesarian_df.to_excel('E:/1.Saya/Kuliah/Semester 7/BI/UAS/Hasil/Hasil_KNN_4A.xlsx')

# %%
import math 
dis = []
for i in range(80):
    dis.append(math.sqrt((float(caesarian_df.iloc[i]['Usia'])-35)**2+
                         (float(caesarian_df.iloc[i]['Kelahiran_ke-'])- 2)**2+
                         (float(caesarian_df.iloc[i]['Waktu_Kelahiran'])-0)**2+
                         (float(caesarian_df.iloc[i]['Tekanan_darah'])-2)**2))

# %%
caesarian_df['dis'] = dis
caesarian_df
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 0     22              1                0              2                 0
# 1     26              2                0              1                 0
# 2     26              2                1              1                 0
# 3     28              1                0              2                 0
# 4     22              2                0              1                 0
# ..   ...            ...              ...            ...               ...
# 75    27              2                1              1                 0
# 76    33              4                0              1                 0
# 77    29              2                1              2                 0
# 78    25              1                2              0                 0
# 79    24              2                2              1                 0
#
#     Caesarian        dis
# 0           0  13.038405
# 1           1   9.055385
# ...

# %%
caesarian_df.sort_values('dis')
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 65    35              2                0              1                 0
# 42    36              1                1              2                 0
# 10    36              1                0              1                 0
# 44    36              4                0              2                 1
# 53    35              1                1              0                 0
# ..   ...            ...              ...            ...               ...
# 41    19              1                0              1                 0
# 61    19              1                0              1                 0
# 26    18              1                1              2                 1
# 25    18              1                0              1                 0
# 70    17              1                0              0                 0
#
#     Caesarian        dis
# 65          1   1.000000
# 42          1   1.732051
# ...

# %%
y = caesarian_df.sort_values('dis').head(5)
y
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 65    35              2                0              1                 0
# 42    36              1                1              2                 0
# 10    36              1                0              1                 0
# 44    36              4                0              2                 1
# 53    35              1                1              0                 0
#
#     Caesarian       dis
# 65          1  1.000000
# 42          1  1.732051
# 10          0  1.732051
# 44          1  2.236068
# 53          0  2.449490

# %%
z = y["Caesarian"]
z
# Out:
# 65    1
# 42    1
# 10    0
# 44    1
# 53    0
# Name: Caesarian, dtype: int32

# %%
np.mean(z)
# Out:
# 0.6

# %%
caesarian_df.to_excel('E:/1.Saya/Kuliah/Semester 7/BI/UAS/Hasil/Hasil_KNN_4B.xlsx')
